# %%
import pandas as pd
import json

path = r"/HOME/sysu_grwang/sysu_grwang_1/HDD_POOL/lx/llm_code/router/LLMRouter/llmrouter/data/routerdc/final_test_nq.json"

# %%
with open(path, 'r') as f:
    data = [json.loads(line) for line in f]
    
len(data)
# Out:
# 500

# %%
test = data[:5]
test_path = r"/HOME/sysu_grwang/sysu_grwang_1/HDD_POOL/lx/llm_code/router/LLMRouter/llmrouter/data/routerdc/final_test_nq_split.json"

# 方法1：使用 json.dump 直接写入 JSONL 格式（推荐）
with open(test_path, 'w') as f:
    for item in test:
        f.write(json.dumps(item, ensure_ascii=False) + '\n')

# 方法2：转换为 DataFrame 后使用 to_json（备选）
# test_df = pd.DataFrame(test)
# test_df.to_json(test_path, orient='records', lines=True)
